# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make('LunarLander-v2',render_mode='human')
# env.reset()
# env.render(mode='human')

# %%
episodes = 10

for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info,_ = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-226.29813049269498
# Episode:2 Score:-100.05313260524196
# Episode:3 Score:-96.48914808713462
# Episode:4 Score:-497.02439370308474
# Episode:5 Score:-77.02633596193871
# Episode:6 Score:-98.43263200300768
# Episode:7 Score:-67.48750185104862
# Episode:8 Score:-305.98645305375265
# Episode:9 Score:-140.7168169172627
# Episode:10 Score:-282.7974308389582
# c:\Users\Satyajeet\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\box2d\lunar_lander.py:681: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("LunarLander-v2", render_mode="rgb_array")
#   gym.logger.warn(

# %%
env = gym.make('LunarLander-v2')
env= DummyVecEnv([lambda: env])
# Multi layer perceptron policy
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps =100000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1031 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007263704 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00112    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 749         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00597    |
# |    value_loss           | 1.61e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 520          |
# |    iterations           | 3            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0073183374 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0435      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 245          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00547     |
# |    value_loss           | 848          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 4           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008252949 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00661    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 495         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00839    |
# |    value_loss           | 1e+03       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011825997 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0436     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 250         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00897    |
# |    value_loss           | 617         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 6            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0034781473 |
# |    clip_fraction        | 0.00342      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00907     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 691          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 953          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 429          |
# |    iterations           | 7            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0038365289 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00232     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 284          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.003       |
# |    value_loss           | 569          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 430          |
# |    iterations           | 8            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0097051645 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000196     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 266          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 395          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 431         |
# |    iterations           | 9           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009605135 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.000384   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 174         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00588    |
# |    value_loss           | 403         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 433         |
# |    iterations           | 10          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007150755 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.0174     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 117         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00573    |
# |    value_loss           | 254         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 11          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007349333 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.00192    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 396         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 543         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 12          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007130376 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.0517      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.5        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00654    |
# |    value_loss           | 234         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 436        |
# |    iterations           | 13         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01244973 |
# |    clip_fraction        | 0.147      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.0299     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 132        |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0129    |
# |    value_loss           | 356        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 14          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009810241 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.8        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00959    |
# |    value_loss           | 280         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 15          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010279522 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.174       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 347         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 16          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012678131 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 102         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 293         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 17           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0056942636 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.248        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 210          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00431     |
# |    value_loss           | 396          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 18          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006166527 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00565    |
# |    value_loss           | 265         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 449          |
# |    iterations           | 19           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0071425755 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 130          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00789     |
# |    value_loss           | 361          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 20          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008750901 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.8        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00814    |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 21          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010548603 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 22          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010823438 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.7        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00951    |
# |    value_loss           | 131         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 444          |
# |    iterations           | 23           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0115018785 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.8         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00726     |
# |    value_loss           | 245          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 24          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008989206 |
# |    clip_fraction        | 0.099       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.9        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 166         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 25          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.019848913 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.47        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.8        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 26          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012260539 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.6        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 224         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 429         |
# |    iterations           | 27          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010468327 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00709    |
# |    value_loss           | 135         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 28          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009144627 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00926    |
# |    value_loss           | 94.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 29          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.014064498 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.4        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 90.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 30          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.016325433 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00908    |
# |    value_loss           | 84.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 31          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009682547 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.7        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0071     |
# |    value_loss           | 155         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 32          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009205345 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00378    |
# |    value_loss           | 88.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 33          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010606876 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.92       |
# |    explained_variance   | 0.659       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.6        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 90          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 34           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0087500885 |
# |    clip_fraction        | 0.0877       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.66         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.4         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00628     |
# |    value_loss           | 90.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 35          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010474872 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.1         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 18.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 36          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008517966 |
# |    clip_fraction        | 0.0643      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.5         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 19.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 37          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004969068 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.903      |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 53.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 38          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004778786 |
# |    clip_fraction        | 0.0408      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.8        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00521    |
# |    value_loss           | 87.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 39          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.007080541 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.89       |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00573    |
# |    value_loss           | 21.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 40          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006276626 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.1        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00485    |
# |    value_loss           | 95.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 41           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0064174267 |
# |    clip_fraction        | 0.0885       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.872       |
# |    explained_variance   | 0.91         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.54         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00762     |
# |    value_loss           | 9.51         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 42          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008564742 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.9         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00565    |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 43          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006854982 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.906      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00691    |
# |    value_loss           | 10.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 44          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012509953 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.775      |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.61        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00739    |
# |    value_loss           | 10.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 45           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0062568486 |
# |    clip_fraction        | 0.0726       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.86         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00476     |
# |    value_loss           | 12.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 46          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004614993 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7           |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 39.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 410        |
# |    iterations           | 47         |
# |    time_elapsed         | 234        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.03412959 |
# |    clip_fraction        | 0.325      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.823     |
# |    explained_variance   | 0.639      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.2       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.013     |
# |    value_loss           | 93.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 48          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.017724182 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.763      |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.6        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00735    |
# |    value_loss           | 171         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 49           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0045992658 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.712       |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.56         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 49.2         |
# ------------------------------------------

# %%
model.save('PPO_LunarLander-v1')

# %%
ev = evaluate_policy(model, env, n_eval_episodes=20, render=True)
env.close()
# Out:
# c:\Users\Satyajeet\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# c:\Users\Satyajeet\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:234: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")

# %%
ev
# Out:
# (93.09103102870749, 116.0142647097021)

# %%
obs,_ = env.reset()
while True:
    total_reward = 0
    action, _states = model.predict(obs)
    obs, rewards, dones, _,_ = env.step(action)
    total_reward += rewards
    if dones:
        print("Reward:", total_reward)
        obs = env.reset()
        break
    env.render()
# Out:
# Reward: -100
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
